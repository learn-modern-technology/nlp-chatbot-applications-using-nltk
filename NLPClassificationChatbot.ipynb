# %% [markdown]
# # Text classification using NLP- Core engine of a chatbot.

# %% [markdown]
# - Natural language processing helps computers communicate with humans in their own language and scales other language-related tasks. For example, NLP makes it possible for computers to read text, interpret it, measure sentiment and determine which parts are important. Understanding this will enable us to build the core component of any conversational chatbot. This is the core engine of a conversational chatbot
#
# ** **
# - Detecting patterns is a central part of Natural Language Processing.
# - Words ending in -ed tend to be past tense verbs.
# - Frequent use of will is indicative of news text
# - These observable patterns — word structure and word frequency — happen to correlate with particular aspects of meaning, such as tense and topic.
#
# ** **
# - But how did we know where to start looking, which aspects of form to associate with which aspects of meaning? Through this exercise we will learn to create the core engine of a chat bot.
# - We will also learn text classification using the techniques of natural language processing.

# %%
import nltk

# %%
# nltk.download('popular')

# %%
import os
import re
import numpy as np
import pandas as pd
import random
import csv

from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer, word_tokenize, sent_tokenize
from nltk.classify import SklearnClassifier

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
stop_words = stopwords.words('english')
type(stop_words)
# Out:
# list

# %%
def data_preprocessing(text):
    text = text.lower()    #Converting to text to lowercase
    text = re.sub(r'[^\w\s]','',text) #Removing hashtags
    text_tokens = word_tokenize(text)
    filtered_text = [word for word in text_tokens if word not in stop_words]
    # preprocessed_text = ' '.join(filtered_text)
    return filtered_text

# %% [markdown]
# POS tag list:
#
# - CC coordinating conjunction
# - CD cardinal digit
# - DT determiner
# - EX existential there (like: "there is" ... think of it like "there exists")
# - FW foreign word
# - IN preposition/subordinating conjunction
# - JJ adjective 'big'
# - JJR adjective, comparative 'bigger'
# - JJS adjective, superlative 'biggest'
# - LS list marker 1)
# - MD modal could, will
# - NN noun, singular 'desk'
# - NNS noun plural 'desks'
# - NNP proper noun, singular 'Harrison'
# - NNPS proper noun, plural 'Americans'
# - PDT predeterminer 'all the kids'
# - POS possessive ending parent's
# - PRP personal pronoun I, he, she
# - PRP'$'$ possessive pronoun my, his, hers
# - RB adverb very, silently,
# - RBR adverb, comparative better
# - RBS adverb, superlative best
# - RP particle give up
# - TO to go 'to' the store.
# - UH interjection errrrrrrrm
# - VB verb, base form take
# - VBD verb, past tense took
# - VBG verb, gerund/present participle taking
# - VBN verb, past participle taken
# - VBP verb, sing. present, non-3d take
# - VBZ verb, 3rd person sing. present takes
# - WDT wh-determiner which
# - WP wh-pronoun who, what
# - WP$ possessive wh-pronoun whose
# - WRB wh-abverb where, when

# %%
def part_of_speech_tags(text):
    return nltk.pos_tag(text)

# %%
def extract_pos_tags(sentences):
    features = []
    for tagged_word in sentences:
        word, tag = tagged_word
        if tag=='NN' or tag == 'VBN' or tag == 'NNS' or tag == 'VBP' or tag == 'RB' or tag == 'VBZ' or tag == 'VBG' or tag =='PRP' or tag == 'JJ':
            features.append(word)
    return features

# %%
def extract_feature(text):
    lemmantizer = WordNetLemmatizer() 
    words = data_preprocessing(text)
    #print('words: ',words)
    tags = part_of_speech_tags(words)
    #print('tags: ',tags)
    extracted_features = extract_pos_tags(tags)
    #print('Extracted features: ',extracted_features)
    # stemmed_words = [stemmer.stem(x) for x in extracted_features]
    #print(stemmed_words)

    result = [lemmantizer.lemmatize(x) for x in extracted_features]
   
    return result

# %%
def word_feats(words):
    return dict([(word, True) for word in words])

# %%
def extract_feature_from_doc(data):
    result = []
    corpus = []
    # The responses of the chat bot
    answers = {}
    for (text, category, answer) in data:

        features = extract_feature(text)
        corpus.append(features)
        result.append((word_feats(features), category))
        answers[category] = answer

    return (result, sum(corpus,[]), answers)

# %%
extract_feature_from_doc([['this is the input text from the user','category','answer to give']])
# Out:
# ([({'input': True, 'user': True}, 'category')],
#  ['input', 'user'],
#  {'category': 'answer to give'})

# %%
from sklearn.model_selection import train_test_split

def split_dataset(data, split_ratio=0.2):
    training_dataset, test_dataset = train_test_split(data, test_size=split_ratio, random_state=123)
    print('Shape of training dataset -', len(training_dataset))
    print('Shape of test dataset -', len(test_dataset))
    print('Saving Training dataset and Test dataset -')
    
    # save the data
    np.save('training_data', training_dataset)
    np.save('test_data', test_dataset)
    return training_dataset, test_dataset

# %%
def get_content(filename):
    document = os.path.join(filename)
    data = []
    with open(document, 'r') as content_file:
        lines = csv.reader(content_file, delimiter='|')
        data = [x for x in lines if len(x) == 3]
    return data

# %%
filename = 'leaves.txt'
data = get_content(filename)
data
# Out:
# [['Hello',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hi hello',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hi ',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hi', 'Greetings', 'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hi', 'Greetings', 'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hey',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hello, hi',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hey',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hey, hi',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['hey, hello',
#   'Greetings',
#   'Hello. I am Dexter. I will serve your leave enquiries.'],
#  ['Good morning',
#   'Morning',
#   'Good Morning. I am Dexter. I will serve your leave enquiries.'],
#  ['Good afternoon',
#   'Afternoon',
#   'Good afternoon. I am Dexter. I will serve your leave enquiries.'],
#  ['Good evening',
#   'Evening',
#   'Good evening. I am Dexter. I will serve your leave enquiries.'],
#  ['Good night', 'Goodbye', 'Good night. Take care.'],
#  ['How are you today?', 'Opening', "I'm fine! Thank you. How can I help you?"],
#  ['want help', 'Help', 'How can I help you?'],
#  ['need help', 'Help', 'How can I help you?'],
#  ['help me', 'Help', 'How can I help you?'],
#  ["I don't want your help.",
#   'No-Help',
#   'Ok sir/madam. No problem. Have a nice day.'],
#  ["I don't want your assistance",
#   'No-Help',
#   'Ok sir/madam. No problem. Have a nice day.'],
#  ['No help required', 'No-Help', 'Ok sir/madam. No problem. Have a nice day.'],
#  ['It has been great talking to you.',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['great',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thank you for your help',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thank you',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thank you very much',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thanks.',
#   'Closing',
#   "You're welcome!It's glad to know that I have been helpful. Have a good day!"],
#  ['thanks very much',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['How many types of leaves are there?',
#   'Leaves-Type',
#   'Currently I know about two: annual and optional leaves.'],
#  ['types of leaves?',
#   'Leaves-Type',
#   'Currently I know about two: annual and optional leaves.'],
#  ['type leaves?',
#   'Leaves-Type',
#   'Currently I know about two: annual and optional leaves.'],
#  ['leave type?',
#   'Leaves-Type',
#   'Currently I know about two: annual and optional leaves.'],
#  ['leaves type?',
#   'Leaves-Type',
#   'Currently I know about two: annual and optional leaves.'],
#  ['How many leaves have I taken?',
#   'Default-Utilized-Annual-Leaves',
#   'You have used 12 annual leaves.'],
#  ['How many leaves I have already taken?',
#   'Default-Utilized-Annual-Leaves',
#   'You have used 12 annual leaves.'],
#  ['how many annual leaves I took?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['How many annual leaves have I taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['How many annual leaves I have already taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['Tell me the annual leaves count I have taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['How many annual leaves have I taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['number of annual leaves taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['annual leaves taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['number of annual leaves already taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['annual leaves taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['annual leaves already taken?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['Tell me number of annual leaves I have taken',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['number of annual leaves used?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['my taken annual leaves',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['annual leaves used?',
#   'Utilized-Annual-Leaves',
#   'You have taken 12 annual leaves.'],
#  ['How many optional leaves have I taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['How many optional leaves I took',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['optional leaves taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['number of optional leaves I have taken?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me the optional leaves count I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me number of optional leaves I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['can you tell me number of optional leaves I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['please tell me number of optional leaves I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['How many optional leaves have I taken?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['number of optional leaves taken?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['number of optional leaves already taken?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['optional leaves taken?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['optional leaves already taken?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['please tell me number of optional leaves I have used.',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['please tell me number of optional leaves I have used',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me the optional leaves count I have used.',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me the optional leaves count I have used',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['the optional leaves count I have used',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['the optional leaves count I have used?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me the optional leaves count I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me the optional leaves count I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['tell me the optional leaves count I have taken',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['How many optional leaves have I used',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['How many optional leaves have I used?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['number of optional leaves used?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['optional leaves used?',
#   'Utilized-Optional-Leaves',
#   'You have taken 1 optional leaves.'],
#  ['How many leaves do I have?',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['How many leaves can I take?',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['How many leaves are remaining?',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['remaining leaves.',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['What are my leaves?',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['Tell me my leave balance.',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['my remaining leaves.',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['leave balance.',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['leaves pending.',
#   'Default-Balance-Annual-Leaves',
#   'You have 25 annual leaves left.'],
#  ['tell me the annual leaves count I have remaining',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['How many annual leaves do I have?',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['What are my annual leaves?',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['What is my annual leave balance?',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['Tell me my annual leaves.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['How many annual leaves are remaining?',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['Tell me my annual leaves remaining',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['remaining annual leaves.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['annual leaves remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['number of annual leaves remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['number of annual leaves I have?',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['annual leaves remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['Please tell me the annual leaves count I have remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['Tell me the annual leaves count I have remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['the annual leaves count I have remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['my annual leaves count remaining.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['Tell me my annual leave balance.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['annual leave balance.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['annual leaves.',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['can you tell me number of annual leaves I have remaining',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['please tell me number of annual leaves I have remaining',
#   'Balance-Annual-Leaves',
#   'You have 25 annual leaves remaining.'],
#  ['How many optional leaves are remaining?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['optional leaves remaining?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['number of optional leaves I have remaining?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['How many optional leaves do I have?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['How many optional leaves do I have',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['Tell me my optional leave balance?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['Tell me my optional leaves left?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['How many optional leaves can I take?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['optional leaves take?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['How many optional leaves I have?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['Tell me my optional leave balance.',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['tell me the optional leaves count I have remaining',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['optional leaves.',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['optional leaves?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['optional leave balance',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['optional',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['Tell me the optional leaves count I have remaining.',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['the optional leaves count I have remaining?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['my optional leaves count remaining.',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['please tell me number of optional leaves I have remaining',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['please tell me number of optional leaves I have remaining.',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['number of optional leaves I have remaining.',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['number of optional leaves I have',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['number of optional leaves?',
#   'Balance-Optional-Leaves',
#   'You have 2 optional leaves remaining.'],
#  ['How many carry forward leaves do I have?',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['number of carry forward leaves I have?',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['tell me the carry forward leaves count I have',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['tell me number of carry forward leaves I have',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['can you tell me number of carry forward leaves I have',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['please tell me number of carry forward leaves I have',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['How many carry forwards do I have from previous year?',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['Tell me my carry forward leaves from previous year',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['Tell me my carry forward leaves',
#   'CF',
#   'You have 30 carry forward leaves.'],
#  ['Tell me carry forward leaves', 'CF', 'You have 30 carry forward leaves.'],
#  ['carry forward leaves', 'CF', 'You have 30 carry forward leaves.'],
#  ['carry forward leave', 'CF', 'You have 30 carry forward leaves.'],
#  ['carry forward', 'CF', 'You have 30 carry forward leaves.'],
#  ['previous year carry forward leaves',
#   'CF',
#   'You have 30 carry forward leaves.']]

# %%
features_data, corpus, answers = extract_feature_from_doc(data)

# %%
features_data
# Out:
# [({'hello': True}, 'Greetings'),
#  ({'hi': True, 'hello': True}, 'Greetings'),
#  ({'hi': True}, 'Greetings'),
#  ({'hi': True}, 'Greetings'),
#  ({'hi': True}, 'Greetings'),
#  ({'hey': True}, 'Greetings'),
#  ({'hello': True, 'hi': True}, 'Greetings'),
#  ({'hey': True}, 'Greetings'),
#  ({'hey': True, 'hi': True}, 'Greetings'),
#  ({'hey': True, 'hello': True}, 'Greetings'),
#  ({'good': True, 'morning': True}, 'Morning'),
#  ({'good': True, 'afternoon': True}, 'Afternoon'),
#  ({'good': True, 'evening': True}, 'Evening'),
#  ({'good': True, 'night': True}, 'Goodbye'),
#  ({'today': True}, 'Opening'),
#  ({'want': True, 'help': True}, 'Help'),
#  ({'need': True, 'help': True}, 'Help'),
#  ({'help': True}, 'Help'),
#  ({'dont': True, 'want': True, 'help': True}, 'No-Help'),
#  ({'dont': True, 'want': True, 'assistance': True}, 'No-Help'),
#  ({'help': True}, 'No-Help'),
#  ({'great': True, 'talking': True}, 'Closing'),
#  ({'great': True}, 'Closing'),
#  ({'thank': True, 'help': True}, 'Closing'),
#  ({'thank': True}, 'Closing'),
#  ({'thank': True, 'much': True}, 'Closing'),
#  ({'thanks': True}, 'Closing'),
#  ({'thanks': True, 'much': True}, 'Closing'),
#  ({'many': True, 'type': True, 'leaf': True}, 'Leaves-Type'),
#  ({'type': True, 'leaf': True}, 'Leaves-Type'),
#  ({'type': True, 'leaf': True}, 'Leaves-Type'),
#  ({'type': True}, 'Leaves-Type'),
#  ({'leaf': True, 'type': True}, 'Leaves-Type'),
#  ({'many': True, 'leaf': True, 'taken': True},
#   'Default-Utilized-Annual-Leaves'),
#  ({'many': True, 'leaf': True, 'already': True, 'taken': True},
#   'Default-Utilized-Annual-Leaves'),
#  ({'many': True, 'annual': True, 'leaf': True}, 'Utilized-Annual-Leaves'),
#  ({'many': True, 'annual': True, 'leaf': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'many': True, 'annual': True, 'leaf': True, 'already': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'count': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'many': True, 'annual': True, 'leaf': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'taken': True}, 'Utilized-Annual-Leaves'),
#  ({'number': True,
#    'annual': True,
#    'leaf': True,
#    'already': True,
#    'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'taken': True}, 'Utilized-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'already': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True, 'taken': True},
#   'Utilized-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True}, 'Utilized-Annual-Leaves'),
#  ({'taken': True, 'annual': True, 'leaf': True}, 'Utilized-Annual-Leaves'),
#  ({'annual': True, 'leaf': True}, 'Utilized-Annual-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True}, 'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'taken': True}, 'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True,
#    'optional': True,
#    'leaf': True,
#    'already': True,
#    'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'taken': True}, 'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'already': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True},
#   'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'used': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'used': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'used': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'used': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'taken': True},
#   'Utilized-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True}, 'Utilized-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True}, 'Utilized-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True},
#   'Utilized-Optional-Leaves'),
#  ({'optional': True, 'leaf': True}, 'Utilized-Optional-Leaves'),
#  ({'many': True, 'leaf': True}, 'Default-Balance-Annual-Leaves'),
#  ({'many': True, 'leaf': True, 'take': True}, 'Default-Balance-Annual-Leaves'),
#  ({'many': True, 'leaf': True, 'remaining': True},
#   'Default-Balance-Annual-Leaves'),
#  ({'remaining': True, 'leaf': True}, 'Default-Balance-Annual-Leaves'),
#  ({'leaf': True}, 'Default-Balance-Annual-Leaves'),
#  ({'tell': True, 'leave': True, 'balance': True},
#   'Default-Balance-Annual-Leaves'),
#  ({'remaining': True, 'leaf': True}, 'Default-Balance-Annual-Leaves'),
#  ({'leave': True, 'balance': True}, 'Default-Balance-Annual-Leaves'),
#  ({'leaf': True, 'pending': True}, 'Default-Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'many': True, 'annual': True, 'leaf': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leave': True, 'balance': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True}, 'Balance-Annual-Leaves'),
#  ({'many': True, 'annual': True, 'leaf': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'remaining': True}, 'Balance-Annual-Leaves'),
#  ({'remaining': True, 'annual': True, 'leaf': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'remaining': True}, 'Balance-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'remaining': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'annual': True, 'leave': True, 'balance': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leave': True, 'balance': True}, 'Balance-Annual-Leaves'),
#  ({'annual': True, 'leaf': True}, 'Balance-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'number': True, 'annual': True, 'leaf': True, 'remaining': True},
#   'Balance-Annual-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'optional': True, 'leave': True, 'balance': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True, 'take': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'take': True}, 'Balance-Optional-Leaves'),
#  ({'many': True, 'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'optional': True, 'leave': True, 'balance': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'optional': True, 'leave': True, 'balance': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True}, 'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'optional': True, 'leaf': True, 'count': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True, 'remaining': True},
#   'Balance-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'number': True, 'optional': True, 'leaf': True}, 'Balance-Optional-Leaves'),
#  ({'many': True, 'carry': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'number': True, 'carry': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'tell': True, 'carry': True, 'forward': True, 'leaf': True, 'count': True},
#   'CF'),
#  ({'number': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'number': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'number': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'many': True,
#    'carry': True,
#    'forward': True,
#    'previous': True,
#    'year': True},
#   'CF'),
#  ({'tell': True,
#    'carry': True,
#    'forward': True,
#    'leaf': True,
#    'previous': True,
#    'year': True},
#   'CF'),
#  ({'tell': True, 'carry': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'tell': True, 'carry': True, 'forward': True, 'leaf': True}, 'CF'),
#  ({'forward': True, 'leaf': True}, 'CF'),
#  ({'carry': True, 'forward': True, 'leave': True}, 'CF'),
#  ({'carry': True, 'forward': True}, 'CF'),
#  ({'previous': True,
#    'year': True,
#    'carry': True,
#    'forward': True,
#    'leaf': True},
#   'CF')]

# %%
corpus
# Out:
# ['hello',
#  'hi',
#  'hello',
#  'hi',
#  'hi',
#  'hi',
#  'hey',
#  'hello',
#  'hi',
#  'hey',
#  'hey',
#  'hi',
#  'hey',
#  'hello',
#  'good',
#  'morning',
#  'good',
#  'afternoon',
#  'good',
#  'evening',
#  'good',
#  'night',
#  'today',
#  'want',
#  'help',
#  'need',
#  'help',
#  'help',
#  'dont',
#  'want',
#  'help',
#  'dont',
#  'want',
#  'assistance',
#  'help',
#  'great',
#  'talking',
#  'great',
#  'thank',
#  'help',
#  'thank',
#  'thank',
#  'much',
#  'thanks',
#  'thanks',
#  'much',
#  'many',
#  'type',
#  'leaf',
#  'type',
#  'leaf',
#  'type',
#  'leaf',
#  'type',
#  'leaf',
#  'type',
#  'many',
#  'leaf',
#  'taken',
#  'many',
#  'leaf',
#  'already',
#  'taken',
#  'many',
#  'annual',
#  'leaf',
#  'many',
#  'annual',
#  'leaf',
#  'taken',
#  'many',
#  'annual',
#  'leaf',
#  'already',
#  'taken',
#  'annual',
#  'leaf',
#  'count',
#  'taken',
#  'many',
#  'annual',
#  'leaf',
#  'taken',
#  'number',
#  'annual',
#  'leaf',
#  'taken',
#  'annual',
#  'leaf',
#  'taken',
#  'number',
#  'annual',
#  'leaf',
#  'already',
#  'taken',
#  'annual',
#  'leaf',
#  'taken',
#  'annual',
#  'leaf',
#  'already',
#  'taken',
#  'number',
#  'annual',
#  'leaf',
#  'taken',
#  'number',
#  'annual',
#  'leaf',
#  'taken',
#  'annual',
#  'leaf',
#  'annual',
#  'leaf',
#  'many',
#  'optional',
#  'leaf',
#  'taken',
#  'many',
#  'optional',
#  'leaf',
#  'optional',
#  'leaf',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'taken',
#  'optional',
#  'leaf',
#  'count',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'taken',
#  'many',
#  'optional',
#  'leaf',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'already',
#  'taken',
#  'optional',
#  'leaf',
#  'taken',
#  'optional',
#  'leaf',
#  'already',
#  'taken',
#  'number',
#  'optional',
#  'leaf',
#  'number',
#  'optional',
#  'leaf',
#  'optional',
#  'leaf',
#  'count',
#  'used',
#  'optional',
#  'leaf',
#  'count',
#  'used',
#  'optional',
#  'leaf',
#  'count',
#  'used',
#  'optional',
#  'leaf',
#  'count',
#  'used',
#  'optional',
#  'leaf',
#  'count',
#  'taken',
#  'optional',
#  'leaf',
#  'count',
#  'taken',
#  'optional',
#  'leaf',
#  'count',
#  'taken',
#  'many',
#  'optional',
#  'leaf',
#  'many',
#  'optional',
#  'leaf',
#  'number',
#  'optional',
#  'leaf',
#  'optional',
#  'leaf',
#  'many',
#  'leaf',
#  'many',
#  'leaf',
#  'take',
#  'many',
#  'leaf',
#  'remaining',
#  'remaining',
#  'leaf',
#  'leaf',
#  'tell',
#  'leave',
#  'balance',
#  'remaining',
#  'leaf',
#  'leave',
#  'balance',
#  'leaf',
#  'pending',
#  'annual',
#  'leaf',
#  'count',
#  'remaining',
#  'many',
#  'annual',
#  'leaf',
#  'annual',
#  'leaf',
#  'annual',
#  'leave',
#  'balance',
#  'annual',
#  'leaf',
#  'many',
#  'annual',
#  'leaf',
#  'remaining',
#  'annual',
#  'leaf',
#  'remaining',
#  'remaining',
#  'annual',
#  'leaf',
#  'annual',
#  'leaf',
#  'remaining',
#  'number',
#  'annual',
#  'leaf',
#  'remaining',
#  'number',
#  'annual',
#  'leaf',
#  'annual',
#  'leaf',
#  'remaining',
#  'annual',
#  'leaf',
#  'count',
#  'remaining',
#  'annual',
#  'leaf',
#  'count',
#  'remaining',
#  'annual',
#  'leaf',
#  'count',
#  'remaining',
#  'annual',
#  'leaf',
#  'count',
#  'remaining',
#  'annual',
#  'leave',
#  'balance',
#  'annual',
#  'leave',
#  'balance',
#  'annual',
#  'leaf',
#  'number',
#  'annual',
#  'leaf',
#  'remaining',
#  'number',
#  'annual',
#  'leaf',
#  'remaining',
#  'many',
#  'optional',
#  'leaf',
#  'remaining',
#  'optional',
#  'leaf',
#  'remaining',
#  'number',
#  'optional',
#  'leaf',
#  'remaining',
#  'many',
#  'optional',
#  'leaf',
#  'many',
#  'optional',
#  'leaf',
#  'optional',
#  'leave',
#  'balance',
#  'optional',
#  'leaf',
#  'many',
#  'optional',
#  'leaf',
#  'take',
#  'optional',
#  'leaf',
#  'take',
#  'many',
#  'optional',
#  'leaf',
#  'optional',
#  'leave',
#  'balance',
#  'optional',
#  'leaf',
#  'count',
#  'remaining',
#  'optional',
#  'leaf',
#  'optional',
#  'leaf',
#  'optional',
#  'leave',
#  'balance',
#  'optional',
#  'optional',
#  'leaf',
#  'count',
#  'remaining',
#  'optional',
#  'leaf',
#  'count',
#  'remaining',
#  'optional',
#  'leaf',
#  'count',
#  'remaining',
#  'number',
#  'optional',
#  'leaf',
#  'remaining',
#  'number',
#  'optional',
#  'leaf',
#  'remaining',
#  'number',
#  'optional',
#  'leaf',
#  'remaining',
#  'number',
#  'optional',
#  'leaf',
#  'number',
#  'optional',
#  'leaf',
#  'many',
#  'carry',
#  'forward',
#  'leaf',
#  'number',
#  'carry',
#  'forward',
#  'leaf',
#  'tell',
#  'carry',
#  'forward',
#  'leaf',
#  'count',
#  'number',
#  'forward',
#  'leaf',
#  'number',
#  'forward',
#  'leaf',
#  'number',
#  'forward',
#  'leaf',
#  'many',
#  'carry',
#  'forward',
#  'previous',
#  'year',
#  'tell',
#  'carry',
#  'forward',
#  'leaf',
#  'previous',
#  'year',
#  'tell',
#  'carry',
#  'forward',
#  'leaf',
#  'tell',
#  'carry',
#  'forward',
#  'leaf',
#  'forward',
#  'leaf',
#  'carry',
#  'forward',
#  'leave',
#  'carry',
#  'forward',
#  'previous',
#  'year',
#  'carry',
#  'forward',
#  'leaf']

# %%
answers
# Out:
# {'Greetings': 'Hello. I am Dexter. I will serve your leave enquiries.',
#  'Morning': 'Good Morning. I am Dexter. I will serve your leave enquiries.',
#  'Afternoon': 'Good afternoon. I am Dexter. I will serve your leave enquiries.',
#  'Evening': 'Good evening. I am Dexter. I will serve your leave enquiries.',
#  'Goodbye': 'Good night. Take care.',
#  'Opening': "I'm fine! Thank you. How can I help you?",
#  'Help': 'How can I help you?',
#  'No-Help': 'Ok sir/madam. No problem. Have a nice day.',
#  'Closing': "It's glad to know that I have been helpful. Have a good day!",
#  'Leaves-Type': 'Currently I know about two: annual and optional leaves.',
#  'Default-Utilized-Annual-Leaves': 'You have used 12 annual leaves.',
#  'Utilized-Annual-Leaves': 'You have taken 12 annual leaves.',
#  'Utilized-Optional-Leaves': 'You have taken 1 optional leaves.',
#  'Default-Balance-Annual-Leaves': 'You have 25 annual leaves left.',
#  'Balance-Annual-Leaves': 'You have 25 annual leaves remaining.',
#  'Balance-Optional-Leaves': 'You have 2 optional leaves remaining.',
#  'CF': 'You have 30 carry forward leaves.'}

# %%
training_data, test_data = split_dataset(features_data, split_ratio=0.2)
# Out:
# Shape of training dataset - 114
# Shape of test dataset - 29
# Saving Training dataset and Test dataset -

# %% [markdown]
# ## Classification using Decision Tree

# %%
def train_using_decision_tree(training_data, test_data):
    classifier = nltk.classify.DecisionTreeClassifier.train(training_data, entropy_cutoff=0.6, support_cutoff=6)
    classifier_name = type(classifier).__name__
    training_set_accuracy = nltk.classify.accuracy(classifier, training_data)
    print('training set accuracy: ', training_set_accuracy)
    test_set_accuracy = nltk.classify.accuracy(classifier, test_data)
    print('test set accuracy: ', test_set_accuracy)
    return classifier, classifier_name, test_set_accuracy, training_set_accuracy

# %%
training_data = np.load('training_data.npy', allow_pickle=True)
test_data = np.load('test_data.npy' , allow_pickle=True)
dtclassifier, classifier_name, test_set_accuracy, training_set_accuracy = train_using_decision_tree(training_data, test_data)
# Out:
# training set accuracy:  0.9210526315789473
# test set accuracy:  0.7241379310344828

# %% [markdown]
# ## Classification using Naive Bayes

# %%
def train_using_naive_bayes(training_data, test_data):
    classifier = nltk.NaiveBayesClassifier.train(training_data)
    classifier_name = type(classifier).__name__
    training_set_accuracy = nltk.classify.accuracy(classifier, training_data)
    test_set_accuracy = nltk.classify.accuracy(classifier, test_data)
    return classifier, classifier_name, test_set_accuracy, training_set_accuracy

# %%
classifier, classifier_name, test_set_accuracy, training_set_accuracy = train_using_naive_bayes(training_data, test_data)
print(training_set_accuracy)
print(test_set_accuracy)
print(len(classifier.most_informative_features()))
classifier.show_most_informative_features()
# Out:
# 0.868421052631579
# 0.7241379310344828
# 74
# Most Informative Features
#                  already = True           Defaul : Utiliz =     12.0 : 1.0
#                     leaf = None           Closin : Balanc =      7.1 : 1.0
#                     many = True           Defaul : Balanc =      6.3 : 1.0
#                    taken = None           Balanc : Utiliz =      4.3 : 1.0
#                     help = True             Help : Closin =      3.9 : 1.0
#                    carry = None           Utiliz : CF     =      3.4 : 1.0
#                    count = True           Utiliz : CF     =      2.8 : 1.0
#                       hi = None           Utiliz : Greeti =      2.7 : 1.0
#                remaining = None           Utiliz : Balanc =      2.4 : 1.0
#                    leave = True           Defaul : CF     =      2.2 : 1.0

# %% [markdown]
# ### Question and Answers Sample

# %%
def reply(input_sentence):
    category = dtclassifier.classify(word_feats(extract_feature(input_sentence)))
    return answers[category]

# %%
response = reply('Hi')
response
response2 = reply('How many annual leaves do I have left?')
response2
response3 = reply('Thanks')
response3
# Out:
# 'Hello. I am Dexter. I will serve your leave enquiries.'
# 'You have 25 annual leaves remaining.'
# "It's glad to know that I have been helpful. Have a good day!"

# %%
response = reply('Good Morning')
response
response2 = reply('I need your help')
response2
response3 = reply('What is my leave balance?')
response3
# Out:
# 'Good afternoon. I am Dexter. I will serve your leave enquiries.'
# 'How can I help you?'
# 'You have 25 annual leaves left.'
